 [232, (50.4500336, 30.5241361)],
 [233, (24.4538352, 54.3774014)],
 [234, (51.5073219, -0.1276474)],
 [235, (38.9074322, -77.0350922)],
 [236, (18.341137, -64.932789)],
 [237, (-34.9058916, -56.1913095)],
 [238, (41.3123363, 69.2787079)],
 [239, (-17.7414972, 168.3150163)],
 [240, (41.903411, 12.4528527)],
 [241, (10.4813175, -66.8796057)],
 [242, (21.0294498, 105.8544441)],
 [243, (51.4816546, -3.1791934)],
 [244, (-13.2820419, -176.1740224)],
 [245, (27.154512, -13.1953921)],
 [246, (15.3538569, 44.2058841)],
 [247, (-15.4164124, 28.2824793)],
 [248, (-17.831773, 31.045686)]]

# %% [markdown]
# Code Starts here

# %%
# importing libraries
import requests
import json
from time import sleep

# %%
# This script extracts openweather data and saves it in a json file

for i in range(iterations):
    url = f"https://api.openweathermap.org/data/2.5/air_pollution/history?lat={coord[i][1][0]}&lon={coord[i][1][1]}&start=1609459200&end={epoch}&appid=8d9efe95caf3922348a458d615abeb8c"
    response = requests.get(url)
    data = response.json()

    # storing the api response in a json file
    with open(f"air_pollution{coord[i][0]}.json","w") as f:
        json.dump(data,f)
    print(f"open weather zone: {i} done")
    # sleep(1)
# Out:
# open weather zone: 0 done
# open weather zone: 1 done
# open weather zone: 2 done
# open weather zone: 3 done
# open weather zone: 4 done
# open weather zone: 5 done
# open weather zone: 6 done
# open weather zone: 7 done
# open weather zone: 8 done
# open weather zone: 9 done
# open weather zone: 10 done
# open weather zone: 11 done
# open weather zone: 12 done
# open weather zone: 13 done
# open weather zone: 14 done
# open weather zone: 15 done
# open weather zone: 16 done
# open weather zone: 17 done
# open weather zone: 18 done
# open weather zone: 19 done
# open weather zone: 20 done
# open weather zone: 21 done
# open weather zone: 22 done
# open weather zone: 23 done
# open weather zone: 24 done
# open weather zone: 25 done
# open weather zone: 26 done
# open weather zone: 27 done
# open weather zone: 28 done
# open weather zone: 29 done
# open weather zone: 30 done
# open weather zone: 31 done
# open weather zone: 32 done
# open weather zone: 33 done
# open weather zone: 34 done
# open weather zone: 35 done
# open weather zone: 36 done
# open weather zone: 37 done
# open weather zone: 38 done
# open weather zone: 39 done
# open weather zone: 40 done
# open weather zone: 41 done
# open weather zone: 42 done
# open weather zone: 43 done
# open weather zone: 44 done
# open weather zone: 45 done
# open weather zone: 46 done
# open weather zone: 47 done
# open weather zone: 48 done
# open weather zone: 49 done
# open weather zone: 50 done
# open weather zone: 51 done
# open weather zone: 52 done
# open weather zone: 53 done
# open weather zone: 54 done
# open weather zone: 55 done
# open weather zone: 56 done
# open weather zone: 57 done
# open weather zone: 58 done
# open weather zone: 59 done
# open weather zone: 60 done
# open weather zone: 61 done
# open weather zone: 62 done
# open weather zone: 63 done
# open weather zone: 64 done
# open weather zone: 65 done
# open weather zone: 66 done
# open weather zone: 67 done
# open weather zone: 68 done
# open weather zone: 69 done
# open weather zone: 70 done
# open weather zone: 71 done
# open weather zone: 72 done
# open weather zone: 73 done
# open weather zone: 74 done
# open weather zone: 75 done
# open weather zone: 76 done
# open weather zone: 77 done
# open weather zone: 78 done
# open weather zone: 79 done
# open weather zone: 80 done
# open weather zone: 81 done
# open weather zone: 82 done
# open weather zone: 83 done
# open weather zone: 84 done
# open weather zone: 85 done
# open weather zone: 86 done
# open weather zone: 87 done
# open weather zone: 88 done
# open weather zone: 89 done
# open weather zone: 90 done
# open weather zone: 91 done
# open weather zone: 92 done
# open weather zone: 93 done
# open weather zone: 94 done
# open weather zone: 95 done
# open weather zone: 96 done
# open weather zone: 97 done
# open weather zone: 98 done
# open weather zone: 99 done
# open weather zone: 100 done
# open weather zone: 101 done
# open weather zone: 102 done
# open weather zone: 103 done
# open weather zone: 104 done
# open weather zone: 105 done
# open weather zone: 106 done
# open weather zone: 107 done
# open weather zone: 108 done
# open weather zone: 109 done
# open weather zone: 110 done
# open weather zone: 111 done
# open weather zone: 112 done
# open weather zone: 113 done
# open weather zone: 114 done
# open weather zone: 115 done
# open weather zone: 116 done
# open weather zone: 117 done
# open weather zone: 118 done
# open weather zone: 119 done
# open weather zone: 120 done
# open weather zone: 121 done
# open weather zone: 122 done
# open weather zone: 123 done
# open weather zone: 124 done
# open weather zone: 125 done
# open weather zone: 126 done
# open weather zone: 127 done
# open weather zone: 128 done
# open weather zone: 129 done
# open weather zone: 130 done
# open weather zone: 131 done
# open weather zone: 132 done
# open weather zone: 133 done
# open weather zone: 134 done
# open weather zone: 135 done
# open weather zone: 136 done
# open weather zone: 137 done
# open weather zone: 138 done
# open weather zone: 139 done
# open weather zone: 140 done
# open weather zone: 141 done
# open weather zone: 142 done
# open weather zone: 143 done
# open weather zone: 144 done
# open weather zone: 145 done
# open weather zone: 146 done
# open weather zone: 147 done
# open weather zone: 148 done
# open weather zone: 149 done
# open weather zone: 150 done
# open weather zone: 151 done
# open weather zone: 152 done
# open weather zone: 153 done
# open weather zone: 154 done
# open weather zone: 155 done
# open weather zone: 156 done
# open weather zone: 157 done
# open weather zone: 158 done
# open weather zone: 159 done
# open weather zone: 160 done
# open weather zone: 161 done
# open weather zone: 162 done
# open weather zone: 163 done
# open weather zone: 164 done
# open weather zone: 165 done
# open weather zone: 166 done
# open weather zone: 167 done
# open weather zone: 168 done
# open weather zone: 169 done
# open weather zone: 170 done
# open weather zone: 171 done
# open weather zone: 172 done
# open weather zone: 173 done
# open weather zone: 174 done
# open weather zone: 175 done
# open weather zone: 176 done
# open weather zone: 177 done
# open weather zone: 178 done
# open weather zone: 179 done
# open weather zone: 180 done
# open weather zone: 181 done
# open weather zone: 182 done
# open weather zone: 183 done
# open weather zone: 184 done
# open weather zone: 185 done
# open weather zone: 186 done
# open weather zone: 187 done
# open weather zone: 188 done
# open weather zone: 189 done
# open weather zone: 190 done
# open weather zone: 191 done
# open weather zone: 192 done
# open weather zone: 193 done
# open weather zone: 194 done
# open weather zone: 195 done
# open weather zone: 196 done
# open weather zone: 197 done
# open weather zone: 198 done
# open weather zone: 199 done
# open weather zone: 200 done
# open weather zone: 201 done
# open weather zone: 202 done
# open weather zone: 203 done
# open weather zone: 204 done
# open weather zone: 205 done
# open weather zone: 206 done
# open weather zone: 207 done
# open weather zone: 208 done
# open weather zone: 209 done
# open weather zone: 210 done
# open weather zone: 211 done
# open weather zone: 212 done
# open weather zone: 213 done
# open weather zone: 214 done
# open weather zone: 215 done
# open weather zone: 216 done
# open weather zone: 217 done
# open weather zone: 218 done
# open weather zone: 219 done
# open weather zone: 220 done
# open weather zone: 221 done
# open weather zone: 222 done
# open weather zone: 223 done
# open weather zone: 224 done
# open weather zone: 225 done
# open weather zone: 226 done
# open weather zone: 227 done
# open weather zone: 228 done
# open weather zone: 229 done
# open weather zone: 230 done
# open weather zone: 231 done
# open weather zone: 232 done
# open weather zone: 233 done
# open weather zone: 234 done
# open weather zone: 235 done
# open weather zone: 236 done
# open weather zone: 237 done
# open weather zone: 238 done
# open weather zone: 239 done
# open weather zone: 240 done
# open weather zone: 241 done
# open weather zone: 242 done
# open weather zone: 243 done
# open weather zone: 244 done
# open weather zone: 245 done
# open weather zone: 246 done
# open weather zone: 247 done

# %%
# This script extracts meteo data and saves it in a json file

for i in range(iterations):
    url = f"https://archive-api.open-meteo.com/v1/era5?latitude={coord[i][1][0]}&longitude={coord[i][1][1]}&start_date=2021-01-01&end_date={date}&hourly=temperature_2m,dewpoint_2m"
    response = requests.get(url)
    data = response.json()

    # writing to json file
    with open(f"temperature{coord[i][0]}.json", "w") as outfile:
        json.dump(data, outfile)
    print(f"meteo zone: {i} done")
# Out:
# meteo zone: 0 done
# meteo zone: 1 done
# meteo zone: 2 done
# meteo zone: 3 done
# meteo zone: 4 done
# meteo zone: 5 done
# meteo zone: 6 done
# meteo zone: 7 done
# meteo zone: 8 done
# meteo zone: 9 done
# meteo zone: 10 done
# meteo zone: 11 done
# meteo zone: 12 done
# meteo zone: 13 done
# meteo zone: 14 done
# meteo zone: 15 done
# meteo zone: 16 done
# meteo zone: 17 done
# meteo zone: 18 done
# meteo zone: 19 done
# meteo zone: 20 done
# meteo zone: 21 done
# meteo zone: 22 done
# meteo zone: 23 done
# meteo zone: 24 done
# meteo zone: 25 done
# meteo zone: 26 done
# meteo zone: 27 done
# meteo zone: 28 done
# meteo zone: 29 done
# meteo zone: 30 done
# meteo zone: 31 done
# meteo zone: 32 done
# meteo zone: 33 done
# meteo zone: 34 done
# meteo zone: 35 done
# meteo zone: 36 done
# meteo zone: 37 done
# meteo zone: 38 done
# meteo zone: 39 done
# meteo zone: 40 done
# meteo zone: 41 done
# meteo zone: 42 done
# meteo zone: 43 done
# meteo zone: 44 done
# meteo zone: 45 done
# meteo zone: 46 done
# meteo zone: 47 done
# meteo zone: 48 done
# meteo zone: 49 done
# meteo zone: 50 done
# meteo zone: 51 done
# meteo zone: 52 done
# meteo zone: 53 done
# meteo zone: 54 done
# meteo zone: 55 done
# meteo zone: 56 done
# meteo zone: 57 done
# meteo zone: 58 done
# meteo zone: 59 done
# meteo zone: 60 done
# meteo zone: 61 done
# meteo zone: 62 done
# meteo zone: 63 done
# meteo zone: 64 done
# meteo zone: 65 done
# meteo zone: 66 done
# meteo zone: 67 done
# meteo zone: 68 done
# meteo zone: 69 done
# meteo zone: 70 done
# meteo zone: 71 done
# meteo zone: 72 done
# meteo zone: 73 done
# meteo zone: 74 done
# meteo zone: 75 done
# meteo zone: 76 done
# meteo zone: 77 done
# meteo zone: 78 done
# meteo zone: 79 done
# meteo zone: 80 done
# meteo zone: 81 done
# meteo zone: 82 done
# meteo zone: 83 done
# meteo zone: 84 done
# meteo zone: 85 done
# meteo zone: 86 done
# meteo zone: 87 done
# meteo zone: 88 done
# meteo zone: 89 done
# meteo zone: 90 done
# meteo zone: 91 done
# meteo zone: 92 done
# meteo zone: 93 done
# meteo zone: 94 done
# meteo zone: 95 done
# meteo zone: 96 done
# meteo zone: 97 done
# meteo zone: 98 done
# meteo zone: 99 done
# meteo zone: 100 done
# meteo zone: 101 done
# meteo zone: 102 done
# meteo zone: 103 done
# meteo zone: 104 done
# meteo zone: 105 done
# meteo zone: 106 done
# meteo zone: 107 done
# meteo zone: 108 done
# meteo zone: 109 done
# meteo zone: 110 done
# meteo zone: 111 done
# meteo zone: 112 done
# meteo zone: 113 done
# meteo zone: 114 done
# meteo zone: 115 done
# meteo zone: 116 done
# meteo zone: 117 done
# meteo zone: 118 done
# meteo zone: 119 done
# meteo zone: 120 done
# meteo zone: 121 done
# meteo zone: 122 done
# meteo zone: 123 done
# meteo zone: 124 done
# meteo zone: 125 done
# meteo zone: 126 done
# meteo zone: 127 done
# meteo zone: 128 done
# meteo zone: 129 done
# meteo zone: 130 done
# meteo zone: 131 done
# meteo zone: 132 done
# meteo zone: 133 done
# meteo zone: 134 done
# meteo zone: 135 done
# meteo zone: 136 done
# meteo zone: 137 done
# meteo zone: 138 done
# meteo zone: 139 done
# meteo zone: 140 done
# meteo zone: 141 done
# meteo zone: 142 done
# meteo zone: 143 done
# meteo zone: 144 done
# meteo zone: 145 done
# meteo zone: 146 done
# meteo zone: 147 done
# meteo zone: 148 done
# meteo zone: 149 done
# meteo zone: 150 done
# meteo zone: 151 done
# meteo zone: 152 done
# meteo zone: 153 done
# meteo zone: 154 done
# meteo zone: 155 done
# meteo zone: 156 done
# meteo zone: 157 done
# meteo zone: 158 done
# meteo zone: 159 done
# meteo zone: 160 done
# meteo zone: 161 done
# meteo zone: 162 done
# meteo zone: 163 done
# meteo zone: 164 done
# meteo zone: 165 done
# meteo zone: 166 done
# meteo zone: 167 done
# meteo zone: 168 done
# meteo zone: 169 done
# meteo zone: 170 done
# meteo zone: 171 done
# meteo zone: 172 done
# meteo zone: 173 done
# meteo zone: 174 done
# meteo zone: 175 done
# meteo zone: 176 done
# meteo zone: 177 done
# meteo zone: 178 done
# meteo zone: 179 done
# meteo zone: 180 done
# meteo zone: 181 done
# meteo zone: 182 done
# meteo zone: 183 done
# meteo zone: 184 done
# meteo zone: 185 done
# meteo zone: 186 done
# meteo zone: 187 done
# meteo zone: 188 done
# meteo zone: 189 done
# meteo zone: 190 done
# meteo zone: 191 done
# meteo zone: 192 done
# meteo zone: 193 done
# meteo zone: 194 done
# meteo zone: 195 done
# meteo zone: 196 done
# meteo zone: 197 done
# meteo zone: 198 done
# meteo zone: 199 done
# meteo zone: 200 done
# meteo zone: 201 done
# meteo zone: 202 done
# meteo zone: 203 done
# meteo zone: 204 done
# meteo zone: 205 done
# meteo zone: 206 done
# meteo zone: 207 done
# meteo zone: 208 done
# meteo zone: 209 done
# meteo zone: 210 done
# meteo zone: 211 done
# meteo zone: 212 done
# meteo zone: 213 done
# meteo zone: 214 done
# meteo zone: 215 done
# meteo zone: 216 done
# meteo zone: 217 done
# meteo zone: 218 done
# meteo zone: 219 done
# meteo zone: 220 done
# meteo zone: 221 done
# meteo zone: 222 done
# meteo zone: 223 done
# meteo zone: 224 done
# meteo zone: 225 done
# meteo zone: 226 done
# meteo zone: 227 done
# meteo zone: 228 done
# meteo zone: 229 done
# meteo zone: 230 done
# meteo zone: 231 done
# meteo zone: 232 done
# meteo zone: 233 done
# meteo zone: 234 done
# meteo zone: 235 done
# meteo zone: 236 done
# meteo zone: 237 done
# meteo zone: 238 done
# meteo zone: 239 done
# meteo zone: 240 done
# meteo zone: 241 done
# meteo zone: 242 done
# meteo zone: 243 done
# meteo zone: 244 done
# meteo zone: 245 done
# meteo zone: 246 done
# meteo zone: 247 done

# %% [markdown]
# Combining Data

# %%
cities = [[1, 'Sukhumi'],
 [2, 'Kabul'],
 [3, 'Episkopi Cantonment'],
 [4, 'Tirana'],
 [5, 'Algiers'],
 [6, 'Pago Pago'],
 [7, 'Andorra la Vella'],
 [8, 'Luanda'],
 [9, 'The Valley'],
 [10, "St. John's"],
 [11, 'Buenos Aires'],
 [12, 'Yerevan'],
 [13, 'Oranjestad'],
 [14, 'Georgetown'],
 [15, 'Canberra'],
 [16, 'Vienna'],
 [17, 'Baku'],
 [18, 'Nassau'],
 [19, 'Manama'],
 [20, 'Dhaka'],
 [21, 'Bridgetown'],
 [22, 'Minsk'],
 [23, 'Brussels'],
 [24, 'Belmopan'],
 [25, 'Porto-Novo'],
 [26, 'Hamilton'],
 [27, 'Thimphu'],
 [28, 'Sucre'],
 [29, 'La Paz'],
 [30, 'Sarajevo'],
 [31, 'Gaborone'],
 [32, 'Brasília'],
 [33, 'Road Town'],
 [34, 'Bandar Seri Begawan'],
 [35, 'Sofia'],
 [36, 'Ouagadougou'],
 [37, 'Bujumbura'],
 [38, 'Phnom Penh'],
 [39, 'Yaoundé'],
 [40, 'Ottawa'],
 [41, 'Praia'],
 [42, 'George Town'],
 [43, 'Bangui'],
 [44, "N'Djamena"],
 [45, 'Santiago'],
 [46, 'Beijing'],
 [47, 'Flying Fish Cove'],
 [48, 'West Island'],
 [49, 'Bogotá'],
 [50, 'Moroni'],
 [51, 'Avarua'],
 [52, 'San José'],
 [53, 'Zagreb'],
 [54, 'Havana'],
 [55, 'Willemstad'],
 [56, 'Nicosia'],
 [57, 'Prague'],
 [58, 'Yamoussoukro'],
 [59, 'Kinshasa'],
 [60, 'Copenhagen'],
 [61, 'Djibouti'],
 [62, 'Roseau'],
 [63, 'Santo Domingo'],
 [64, 'Dili'],
 [65, 'Hanga Roa'],
 [66, 'Quito'],
 [67, 'Cairo'],
 [68, 'San Salvador'],
 [69, 'Malabo'],
 [70, 'Asmara'],
 [71, 'Tallinn'],
 [72, 'Addis Ababa'],
 [73, 'Stanley'],
 [74, 'Tórshavn'],
 [75, 'Palikir'],
 [76, 'Suva'],
 [77, 'Helsinki'],
 [78, 'Paris'],
 [79, 'Cayenne'],
 [80, 'Papeete'],
 [81, 'Libreville'],
 [82, 'Banjul'],
 [83, 'Tbilisi'],
 [84, 'Berlin'],
 [85, 'Accra'],
 [86, 'Gibraltar'],
 [87, 'Athens'],
 [88, 'Nuuk'],
 [89, "St. George's"],
 [90, 'Hagåtña'],
 [91, 'Guatemala City'],
 [92, 'St. Peter Port'],
 [93, 'Conakry'],
 [94, 'Bissau'],
 [95, 'Georgetown'],
 [96, 'Port-au-Prince'],
 [97, 'Tegucigalpa'],
 [98, 'Budapest'],
 [99, 'Reykjavík'],
 [100, 'New Delhi'],
 [101, 'Jakarta'],
 [102, 'Tehran'],
 [103, 'Baghdad'],
 [104, 'Dublin'],
 [105, 'Douglas'],
 [106, 'Jerusalem'],
 [107, 'Rome'],
 [108, 'Kingston'],
 [109, 'Tokyo'],
 [110, 'St. Helier'],
 [111, 'Amman'],
 [112, 'Astana'],
 [113, 'Nairobi'],
 [114, 'Tarawa'],
 [115, 'Pristina'],
 [116, 'Kuwait City'],
 [117, 'Bishkek'],
 [118, 'Vientiane'],
 [119, 'Riga'],
 [120, 'Beirut'],
 [121, 'Maseru'],
 [122, 'Monrovia'],
 [123, 'Tripoli'],
 [124, 'Vaduz'],
 [125, 'Vilnius'],
 [126, 'Luxembourg'],
 [127, 'Skopje'],
 [128, 'Antananarivo'],
 [129, 'Lilongwe'],
 [130, 'Kuala Lumpur'],
 [131, 'Malé'],
 [132, 'Bamako'],
 [133, 'Valletta'],
 [134, 'Majuro'],
 [135, 'Nouakchott'],
 [136, 'Port Louis'],
 [137, 'Mexico City'],
 [138, 'Chisinau'],
 [139, 'Monaco'],
 [140, 'Ulaanbaatar'],
 [141, 'Podgorica'],
 [142, 'Plymouth'],
 [143, 'Rabat'],
 [144, 'Maputo'],
 [145, 'Naypyidaw'],
 [146, 'Stepanakert'],
 [147, 'Windhoek'],
 [148, 'Yaren'],
 [149, 'Kathmandu'],
 [150, 'Amsterdam'],
 [151, 'Nouméa'],
 [152, 'Wellington'],
 [153, 'Managua'],
 [154, 'Niamey'],
 [155, 'Abuja'],
 [156, 'Alofi'],
 [157, 'Kingston'],
 [158, 'Pyongyang'],
 [159, 'Nicosia'],
 [160, 'Belfast'],
 [161, 'Saipan'],
 [162, 'Oslo'],
 [163, 'Muscat'],
 [164, 'Islamabad'],
 [165, 'Ngerulmud'],
 [166, 'Jerusalem'],
 [167, 'Panama City'],
 [168, 'Port Moresby'],
 [169, 'Asunción'],
 [170, 'Lima'],
 [171, 'Manila'],
 [172, 'Adamstown'],
 [173, 'Warsaw'],
 [174, 'Lisbon'],
 [175, 'San Juan'],
 [176, 'Doha'],
 [177, 'Taipei'],
 [178, 'Brazzaville'],
 [179, 'Bucharest'],
 [180, 'Moscow'],
 [181, 'Kigali'],
 [182, 'Gustavia'],
 [183, 'Jamestown'],
 [184, 'Basseterre'],
 [185, 'Castries'],
 [186, 'Marigot'],
 [187, 'St. Pierre'],
 [188, 'Kingstown'],
 [189, 'Apia'],
 [190, 'San Marino'],
 [191, 'Riyadh'],
 [192, 'Edinburgh'],
 [193, 'Dakar'],
 [194, 'Belgrade'],
 [195, 'Victoria'],
 [196, 'Freetown'],
 [197, 'Singapore'],
 [198, 'Philipsburg'],
 [199, 'Bratislava'],
 [200, 'Ljubljana'],
 [201, 'Honiara'],
 [202, 'Mogadishu'],
 [203, 'Hargeisa'],
 [204, 'Pretoria'],
 [205, 'Grytviken'],
 [206, 'Seoul'],
 [207, 'Tskhinvali'],
 [208, 'Juba'],
 [209, 'Madrid'],
 [210, 'Sri Jayawardenapura Kotte'],
 [211, 'Khartoum'],
 [212, 'Paramaribo'],
 [213, 'Mbabane'],
 [214, 'Stockholm'],
 [215, 'Bern'],
 [216, 'Damascus'],
 [217, 'São Tomé'],
 [218, 'Dushanbe'],
 [219, 'Dodoma'],
 [220, 'Bangkok'],
 [221, 'Lomé'],
 [222, 'Nukuʻalofa'],
 [223, 'Tiraspol'],
 [224, 'Port of Spain'],
 [225, 'Edinburgh of the Seven Seas'],
 [226, 'Tunis'],
 [227, 'Ankara'],
 [228, 'Ashgabat'],
 [229, 'Cockburn Town'],
 [230, 'Funafuti'],
 [231, 'Kampala'],
 [232, 'Kiev'],
 [233, 'Abu Dhabi'],
 [234, 'London'],
 [235, 'Washington, D.C.'],
 [236, 'Charlotte Amalie'],
 [237, 'Montevideo'],
 [238, 'Tashkent'],
 [239, 'Port Vila'],
 [240, 'Vatican City'],
 [241, 'Caracas'],
 [242, 'Hanoi'],
 [243, 'Cardiff'],
 [244, 'Mata-Utu'],
 [245, 'El Aaiún'],
 [246, 'Sanaá'],
 [247, 'Lusaka'],
 [248, 'Harare']]

# %%
# this cell combines two json files into one dataframe after all the preprocessing steps

# fucntion for date conversion of openweather data
def convert_date(ts):
    import pandas as pd
    ts=pd.to_datetime(ts, unit='s')
    year=ts.year
    month=ts.month
    day=ts.day
    hour=ts.hour
    return [year, month, day, hour]

# combining the two json files into one dataframe for a particular zone
def combine_data(zone,city):
        import pandas as pd
        import json

        # reading openweather data
        with open(f"air_pollution{zone}.json") as f:
                openweather = json.load(f)

        # getting longitude and latitude
        longitude = openweather['coord']['lon']
        latitude = openweather['coord']['lat']

        # converting openweather data to dataframe
        arr=[convert_date(openweather['list'][i]['dt'])+[zone, city, longitude,latitude,openweather['list'][0]['main']['aqi']]+
                list(openweather['list'][i]['components'].values()) for i in range(len(openweather['list']))]
        openweather = pd.DataFrame(arr, columns=['year','month','day','hour','zone', 'city',
                'longitude','latitude','aqi','co','no','no2','o3','so2','pm2_5','pm10','nh3'])


        # reading meteo data
        with open(f"temperature{zone}.json") as f:
                meteo = json.load(f)
        
        arr=[convert_date(pd.to_datetime(meteo['hourly']['time'][i]))+[longitude,latitude,
                meteo['hourly']['temperature_2m'][i], meteo['hourly']['dewpoint_2m'][i]] for i in range(len(meteo['hourly']['time']))]
        meteo = pd.DataFrame(arr, columns=['year','month','day','hour','longitude','latitude','temperature','dewpt'])
        
        # # reading weatherbit data
        # with open(f"weatherbit/temperature{zone}.json") as f:
        #         weatherbit = json.load(f)

        # arr=[convert_date(weatherbit['data'][i]['ts'])+[longitude,latitude]+[weatherbit['data'][i]['app_temp']
        #         ,weatherbit['data'][i]['dewpt'],weatherbit['data'][i]['weather']['description']] for i in range(len(weatherbit['data']))]
        # weatherbit = pd.DataFrame(arr, columns=['year','month','day','hour','longitude','latitude','temperature','dewpt','condition'])

        # merging openweather and weatherbit data
        print(f"merging openweather and meteo data for zone {zone}")
        return pd.merge(openweather, meteo, on=['year','month','day','hour','longitude','latitude']).drop([8734])

# %%
# concatenating all the dataframes into one
import pandas as pd
pd.concat([combine_data(i,cities[i-1][1]) for i in range(1, iterations+1)]).sort_index(kind='merge').to_csv('combined_data_orig.csv', index=False)
# Out:
# merging openweather and meteo data for zone 1
# merging openweather and meteo data for zone 2
# merging openweather and meteo data for zone 3
# merging openweather and meteo data for zone 4
# merging openweather and meteo data for zone 5
# merging openweather and meteo data for zone 6
# merging openweather and meteo data for zone 7
# merging openweather and meteo data for zone 8
# merging openweather and meteo data for zone 9
# merging openweather and meteo data for zone 10
# merging openweather and meteo data for zone 11
# merging openweather and meteo data for zone 12
# merging openweather and meteo data for zone 13
# merging openweather and meteo data for zone 14
# merging openweather and meteo data for zone 15
# merging openweather and meteo data for zone 16
# merging openweather and meteo data for zone 17
# merging openweather and meteo data for zone 18
# merging openweather and meteo data for zone 19
# merging openweather and meteo data for zone 20
# merging openweather and meteo data for zone 21
# merging openweather and meteo data for zone 22
# merging openweather and meteo data for zone 23
# merging openweather and meteo data for zone 24
# merging openweather and meteo data for zone 25
# merging openweather and meteo data for zone 26
# merging openweather and meteo data for zone 27
# merging openweather and meteo data for zone 28
# merging openweather and meteo data for zone 29
# merging openweather and meteo data for zone 30
# merging openweather and meteo data for zone 31
# merging openweather and meteo data for zone 32
# merging openweather and meteo data for zone 33
# merging openweather and meteo data for zone 34
# merging openweather and meteo data for zone 35
# merging openweather and meteo data for zone 36
# merging openweather and meteo data for zone 37
# merging openweather and meteo data for zone 38
# merging openweather and meteo data for zone 39
# merging openweather and meteo data for zone 40
# merging openweather and meteo data for zone 41
# merging openweather and meteo data for zone 42
# merging openweather and meteo data for zone 43
# merging openweather and meteo data for zone 44
# merging openweather and meteo data for zone 45
# merging openweather and meteo data for zone 46
# merging openweather and meteo data for zone 47
# merging openweather and meteo data for zone 48
# merging openweather and meteo data for zone 49
# merging openweather and meteo data for zone 50
# merging openweather and meteo data for zone 51
# merging openweather and meteo data for zone 52
# merging openweather and meteo data for zone 53
# merging openweather and meteo data for zone 54
# merging openweather and meteo data for zone 55
# merging openweather and meteo data for zone 56
# merging openweather and meteo data for zone 57
# merging openweather and meteo data for zone 58
# merging openweather and meteo data for zone 59
# merging openweather and meteo data for zone 60
# merging openweather and meteo data for zone 61
# merging openweather and meteo data for zone 62
# merging openweather and meteo data for zone 63
# merging openweather and meteo data for zone 64
# merging openweather and meteo data for zone 65
# merging openweather and meteo data for zone 66
# merging openweather and meteo data for zone 67
# merging openweather and meteo data for zone 68
# merging openweather and meteo data for zone 69
# merging openweather and meteo data for zone 70
# merging openweather and meteo data for zone 71
# merging openweather and meteo data for zone 72
# merging openweather and meteo data for zone 73
# merging openweather and meteo data for zone 74
# merging openweather and meteo data for zone 75
# merging openweather and meteo data for zone 76
# merging openweather and meteo data for zone 77
# merging openweather and meteo data for zone 78
# merging openweather and meteo data for zone 79
# merging openweather and meteo data for zone 80
# merging openweather and meteo data for zone 81
# merging openweather and meteo data for zone 82
# merging openweather and meteo data for zone 83
# merging openweather and meteo data for zone 84
# merging openweather and meteo data for zone 85
# merging openweather and meteo data for zone 86
# merging openweather and meteo data for zone 87
# merging openweather and meteo data for zone 88
# merging openweather and meteo data for zone 89
# merging openweather and meteo data for zone 90
# merging openweather and meteo data for zone 91
# merging openweather and meteo data for zone 92
# merging openweather and meteo data for zone 93
# merging openweather and meteo data for zone 94
# merging openweather and meteo data for zone 95
# merging openweather and meteo data for zone 96
# merging openweather and meteo data for zone 97
# merging openweather and meteo data for zone 98
# merging openweather and meteo data for zone 99
# merging openweather and meteo data for zone 100
# merging openweather and meteo data for zone 101
# merging openweather and meteo data for zone 102
# merging openweather and meteo data for zone 103
# merging openweather and meteo data for zone 104
# merging openweather and meteo data for zone 105
# merging openweather and meteo data for zone 106
# merging openweather and meteo data for zone 107
# merging openweather and meteo data for zone 108
# merging openweather and meteo data for zone 109
# merging openweather and meteo data for zone 110
# merging openweather and meteo data for zone 111
# merging openweather and meteo data for zone 112
# merging openweather and meteo data for zone 113
# merging openweather and meteo data for zone 114
# merging openweather and meteo data for zone 115
# merging openweather and meteo data for zone 116
# merging openweather and meteo data for zone 117
# merging openweather and meteo data for zone 118
# merging openweather and meteo data for zone 119
# merging openweather and meteo data for zone 120
# merging openweather and meteo data for zone 121
# merging openweather and meteo data for zone 122
# merging openweather and meteo data for zone 123
# merging openweather and meteo data for zone 124
# merging openweather and meteo data for zone 125
# merging openweather and meteo data for zone 126
# merging openweather and meteo data for zone 127
# merging openweather and meteo data for zone 128
# merging openweather and meteo data for zone 129
# merging openweather and meteo data for zone 130
# merging openweather and meteo data for zone 131
# merging openweather and meteo data for zone 132
# merging openweather and meteo data for zone 133
# merging openweather and meteo data for zone 134
# merging openweather and meteo data for zone 135
# merging openweather and meteo data for zone 136
# merging openweather and meteo data for zone 137
# merging openweather and meteo data for zone 138
# merging openweather and meteo data for zone 139
# merging openweather and meteo data for zone 140
# merging openweather and meteo data for zone 141
# merging openweather and meteo data for zone 142
# merging openweather and meteo data for zone 143
# merging openweather and meteo data for zone 144
# merging openweather and meteo data for zone 145
# merging openweather and meteo data for zone 146
# merging openweather and meteo data for zone 147
# merging openweather and meteo data for zone 148
# merging openweather and meteo data for zone 149
# merging openweather and meteo data for zone 150
# merging openweather and meteo data for zone 151
# merging openweather and meteo data for zone 152
# merging openweather and meteo data for zone 153
# merging openweather and meteo data for zone 154
# merging openweather and meteo data for zone 155
# merging openweather and meteo data for zone 156
# merging openweather and meteo data for zone 157
# merging openweather and meteo data for zone 158
# merging openweather and meteo data for zone 159
# merging openweather and meteo data for zone 160
# merging openweather and meteo data for zone 161
# merging openweather and meteo data for zone 162
# merging openweather and meteo data for zone 163
# merging openweather and meteo data for zone 164
# merging openweather and meteo data for zone 165
# merging openweather and meteo data for zone 166
# merging openweather and meteo data for zone 167
# merging openweather and meteo data for zone 168
# merging openweather and meteo data for zone 169
# merging openweather and meteo data for zone 170
# merging openweather and meteo data for zone 171
# merging openweather and meteo data for zone 172
# merging openweather and meteo data for zone 173
# merging openweather and meteo data for zone 174
# merging openweather and meteo data for zone 175
# merging openweather and meteo data for zone 176
# merging openweather and meteo data for zone 177
# merging openweather and meteo data for zone 178
# merging openweather and meteo data for zone 179
# merging openweather and meteo data for zone 180
# merging openweather and meteo data for zone 181
# merging openweather and meteo data for zone 182
# merging openweather and meteo data for zone 183
# merging openweather and meteo data for zone 184
# merging openweather and meteo data for zone 185
# merging openweather and meteo data for zone 186
# merging openweather and meteo data for zone 187
# merging openweather and meteo data for zone 188
# merging openweather and meteo data for zone 189
# merging openweather and meteo data for zone 190
# merging openweather and meteo data for zone 191
# merging openweather and meteo data for zone 192
# merging openweather and meteo data for zone 193
# merging openweather and meteo data for zone 194
# merging openweather and meteo data for zone 195
# merging openweather and meteo data for zone 196
# merging openweather and meteo data for zone 197
# merging openweather and meteo data for zone 198
# merging openweather and meteo data for zone 199
# merging openweather and meteo data for zone 200
# merging openweather and meteo data for zone 201
# merging openweather and meteo data for zone 202
# merging openweather and meteo data for zone 203
# merging openweather and meteo data for zone 204
# merging openweather and meteo data for zone 205
# merging openweather and meteo data for zone 206
# merging openweather and meteo data for zone 207
# merging openweather and meteo data for zone 208
# merging openweather and meteo data for zone 209
# merging openweather and meteo data for zone 210
# merging openweather and meteo data for zone 211
# merging openweather and meteo data for zone 212
# merging openweather and meteo data for zone 213
# merging openweather and meteo data for zone 214
# merging openweather and meteo data for zone 215
# merging openweather and meteo data for zone 216
# merging openweather and meteo data for zone 217
# merging openweather and meteo data for zone 218
# merging openweather and meteo data for zone 219
# merging openweather and meteo data for zone 220
# merging openweather and meteo data for zone 221
# merging openweather and meteo data for zone 222
# merging openweather and meteo data for zone 223
# merging openweather and meteo data for zone 224
# merging openweather and meteo data for zone 225
# merging openweather and meteo data for zone 226
# merging openweather and meteo data for zone 227
# merging openweather and meteo data for zone 228
# merging openweather and meteo data for zone 229
# merging openweather and meteo data for zone 230
# merging openweather and meteo data for zone 231
# merging openweather and meteo data for zone 232
# merging openweather and meteo data for zone 233
# merging openweather and meteo data for zone 234
# merging openweather and meteo data for zone 235
# merging openweather and meteo data for zone 236
# merging openweather and meteo data for zone 237
# merging openweather and meteo data for zone 238
# merging openweather and meteo data for zone 239
# merging openweather and meteo data for zone 240
# merging openweather and meteo data for zone 241
# merging openweather and meteo data for zone 242
# merging openweather and meteo data for zone 243
# merging openweather and meteo data for zone 244
# merging openweather and meteo data for zone 245
# merging openweather and meteo data for zone 246
# merging openweather and meteo data for zone 247
# merging openweather and meteo data for zone 248

# %%
# deleting files
import os
for i in range(1, iterations+1):
    os.remove(f"air_pollution{i}.json")
    os.remove(f"temperature{i}.json")

# %%
# # code to download file from google colab
# from google.colab import files
# files.download('combined_data_orig.csv')

# %%
# # colab code to save the data to google drive
# from google.colab import drive
# drive.mount('/content/drive')
# !cp combined_data_orig.csv "/content/drive/My Drive/API Extract/combined_data_orig.csv"
